# %%
from grcnn.model import GRCNN, conv_freq_model
import keras
import numpy as np
# Out:
# Using TensorFlow backend.

# %%
width, height = 160, 32
n_classes = 10
max_text_len = 5
model = conv_freq_model(width, height, n_classes, max_text_len)

# %%
model.summary()
# Out:
# Model: "model_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# input (InputLayer)           [(None, 160, 32, 3)]      0
# _________________________________________________________________
# conv2d_26 (Conv2D)           (None, 160, 32, 16)       1216
# _________________________________________________________________
# re_lu_25 (ReLU)              (None, 160, 32, 16)       0
# _________________________________________________________________
# batch_normalization_24 (Batc (None, 160, 32, 16)       64
# _________________________________________________________________
# conv2d_27 (Conv2D)           (None, 160, 32, 16)       6416
# _________________________________________________________________
# re_lu_26 (ReLU)              (None, 160, 32, 16)       0
# _________________________________________________________________
# batch_normalization_25 (Batc (None, 160, 32, 16)       64
# ...

# %%
# width, height = 128, 32
width, height = 100, 32
n_classes = 11
# max_text_len = 33
max_text_len = 26
model = GRCNN(width, height, n_classes, max_text_len)
# model = keras.models.load_model('model1730.hdf5', compile=False)

# %%
model.summary()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-5f15418b3570> in <module>
# ----> 1 model.summary()
#
# NameError: name 'model' is not defined
