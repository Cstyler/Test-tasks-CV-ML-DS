# %%
from segmodel.data_generation_test import main
# Out:
# Segmentation Models: using `keras` framework.
# Using TensorFlow backend.

# %%
val_img_arr_name = 'dataset1_val'
width, height = 256, 256

# %%
main(val_img_arr_name, height, width)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~/Programms/miniconda3/envs/main/lib/python3.6/site-packages/PIL/ImageFile.py in _save(im, fp, tile, bufsize)
#     505     try:
# --> 506         fh = fp.fileno()
#     507         fp.flush()
#
# AttributeError: '_idat' object has no attribute 'fileno'
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-3-8e98a476dd3a> in <module>
# ----> 1 main(val_img_arr_name, height, width)
#
# ~/PycharmProjects/Severstal_CV_Task/training/segmodel/data_generation_test.py in main(img_arr_name, height, width)
#      25             img_utils.show_img(img_show, figsize)
#      26             img_show = img_utils.apply_mask(img, mask[..., 1], (0, 255, 0), alpha)
# ---> 27             img_utils.show_img(img_show, figsize)
# ...
